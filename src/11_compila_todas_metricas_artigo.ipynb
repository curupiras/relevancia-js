# %% [markdown]
# # Caderno 11 - Compila todas as métricas para o artigo.
#
# As tabelas são as combinações dos conjuntos de queries (3 conjuntos) e k = [5, 10].

# %%
import pandas as pd

# Modelos
MODELOS = ['Luciano/bert-base-portuguese-cased-finetuned-tcu-acordaos',
           'neuralmind/bert-large-portuguese-cased',
           'rufimelo/Legal-BERTimbau-sts-large-ma-v3',
           'stjiris/bert-large-portuguese-cased-legal-mlm-sts-v1.0',   
           'sentence-transformers/paraphrase-multilingual-mpnet-base-v2',
           'text-embedding-3-small',
           'text-embedding-3-large'           
           ]

# Seleciona o tipo de camada oculta
TIPOS_CAMADA_OCULTA = ['mean_hidden_state']

PASTA_DADOS = './dados/'
PASTA_RESULTADO_CADERNO = f'{PASTA_DADOS}outputs/11_compila_todas_metricas_artigo/'
ARQUIVO_METRICAS_BM25 = f'{PASTA_DADOS}outputs/4_metricas_bm25_padrao/metricas_bm25.pickle'
ARQUIVO_METRICAS_ATUAIS = f'{PASTA_DADOS}outputs/3_calcula_metricas_atuais/'
ARQUIVO_MAPA_METRICAS = f'{PASTA_RESULTADO_CADERNO}mapa_metricas.pickle'

# %% [markdown]
# ## 1. Carrega dados de jurisprudência

# %%
import pandas as pd
from metricas import metricas

# A pasta dos JURIS aqui não é a pasta original, e sim o resultado do caderno 1 (os documentos já estão filtrados)
PASTA_JURIS_TCU = f'{PASTA_DADOS}outputs/1_tratamento_juris_tcu/'

# Carrega os arquivos 
def carrega_juris_tcu():
    doc1 = pd.read_csv(f'{PASTA_JURIS_TCU}doc_tratado_parte_1.csv', sep='|')
    doc2 = pd.read_csv(f'{PASTA_JURIS_TCU}doc_tratado_parte_2.csv', sep='|')
    doc3 = pd.read_csv(f'{PASTA_JURIS_TCU}doc_tratado_parte_3.csv', sep='|')
    doc4 = pd.read_csv(f'{PASTA_JURIS_TCU}doc_tratado_parte_4.csv', sep='|')
    doc = pd.concat([doc1, doc2, doc3, doc4], ignore_index=True)
    query = pd.read_csv(f'{PASTA_JURIS_TCU}query_tratado.csv', sep='|')
    qrel = pd.read_csv(f'{PASTA_JURIS_TCU}qrel_tratado.csv', sep='|')

    return doc, query, qrel

docs, queries, qrels = carrega_juris_tcu()

# %% [markdown]
# ## 2. Extrai as métricas
#
# Carrega a lista dos resultados das queries realizadas no banco vetorial.

# %%
import pickle

# Carrega mapa_metricas
try:
    with open(ARQUIVO_MAPA_METRICAS, 'rb') as arquivo:
        mapa_metricas = pickle.load(arquivo)
except FileNotFoundError:
    mapa_metricas = {} 

# Carrega métricas do bm25_padrao
with open(ARQUIVO_METRICAS_BM25, 'rb') as arquivo:
    metricas_bm25_padrao = pickle.load(arquivo)
    
mapa_metricas['bm25_padrao'] = metricas_bm25_padrao

# %%
# Função para encontrar a correspondência entre keys
def find_key(doc_key, docs):
    matches = docs[docs['KEY'].str.contains(doc_key, na=False)]
    if not matches.empty:
        return matches.iloc[0]['KEY']
    return doc_key

# Função que constroi dataframe de resultados no formato esperado pela função de métricas
def processa_resultado(I, docs):
    col_resultado_query_key = []
    col_resultado_doc_key = []
    col_resultado_rank = []

    # Preenchendo as listas
    for query_idx in range(len(I)):
        for rank_idx in range(len(I[0])):
            col_resultado_query_key.append(query_idx + 1)
            col_resultado_doc_key.append(I[query_idx, rank_idx])
            col_resultado_rank.append(rank_idx + 1)

    df_resultados = pd.DataFrame({
        "QUERY_KEY": col_resultado_query_key,
        "DOC_KEY": col_resultado_doc_key,
        "RANK": col_resultado_rank,
    })

    df_resultados['DOC_KEY'] = df_resultados['DOC_KEY'].astype(str)
    df_resultados['DOC_KEY'] = df_resultados['DOC_KEY'].apply(lambda x: find_key(x, docs))
    
    return df_resultados

# Função que verifica se uma chave já existe em um mapa
def verifica_chave(mapa_metricas, chave):
    return chave in mapa_metricas

# %%
import pickle
from metricas import metricas
from tqdm import tqdm

for modelo in tqdm(MODELOS, desc='Processando MODELOS'):
    
    caminho_modelo = modelo.split("/")[-1]
    pasta_resultado_busca = f'{PASTA_DADOS}outputs/8_armazena_dados_em_banco_vetorial/{caminho_modelo}/'
    
    for tipo_camada_oculta in tqdm(TIPOS_CAMADA_OCULTA, desc=f'Processando {modelo}', leave=False):
        
        tipo = tipo_camada_oculta.split('_')[0]
        
        # Se as métricas do modelo já está em mapa_metricas continue
        if verifica_chave(mapa_metricas,f'{caminho_modelo}_{tipo}'):
            continue        
        
        arquivo_resultado_busca = f'{pasta_resultado_busca}{caminho_modelo}_{tipo_camada_oculta}_resultado_query.pickle'
        
        with open(arquivo_resultado_busca, 'rb') as arquivo:
            I = pickle.load(arquivo)
            
        df_resultados = processa_resultado(I, docs)
        metrica_calculada = metricas(df_resultados, qrels, aproximacao_trec_eval=True)
        mapa_metricas[f'{caminho_modelo}_{tipo}'] = metrica_calculada
# Out:
# Processando MODELOS:   0%|          | 0/7 [00:00<?, ?it/s]
# Processando Luciano/bert-base-portuguese-cased-finetuned-tcu-acordaos:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Processando neuralmind/bert-large-portuguese-cased:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Processando rufimelo/Legal-BERTimbau-sts-large-ma-v3:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Processando stjiris/bert-large-portuguese-cased-legal-mlm-sts-v1.0:   0%|          | 0/1 [00:00<?, ?it/s]
#
# Processando sentence-transformers/paraphrase-multilingual-mpnet-base-v2:   0%|          | 0/1 [00:00<?, ?it/s]
# Processando sentence-transformers/paraphrase-multilingual-mpnet-base-v2: 100%|██████████| 1/1 [00:26<00:00, 26.22s/it]
# Processando MODELOS:  71%|███████▏  | 5/7 [00:26<00:10,  5.26s/it]
# Processando text-embedding-3-small:   0%|          | 0/1 [00:00<?, ?it/s]
# Processando text-embedding-3-small: 100%|██████████| 1/1 [00:26<00:00, 26.59s/it]
# Processando MODELOS:  86%|████████▌ | 6/7 [00:52<00:10, 10.01s/it]
# Processando text-embedding-3-large:   0%|          | 0/1 [00:00<?, ?it/s]
# Processando text-embedding-3-large: 100%|██████████| 1/1 [00:29<00:00, 29.02s/it]
# Processando MODELOS: 100%|██████████| 7/7 [01:21<00:00, 11.71s/it]

# %%
verifica_chave(mapa_metricas,f'{caminho_modelo}_{tipo}')
# Out:
# True

# %% [markdown]
# ## 4. Exibe as métricas

# %%
# Imprime as métricas para o conjunto de queries 1 (0:50), 2 (100:150), ou 3 (100:150) 
# e para um determinado k (foi gerado para k = 5, 10, 20 e 50.

def compara_metricas(con_query, k):
    # Acumula as métricas
    precisao = []
    recall = []
    mrr = []
    ndcg = []

    for nome in mapa_metricas.keys():
        estatisticas = mapa_metricas[nome][50*(con_query-1):50*(con_query)].describe()
        precisao.append(estatisticas.loc['mean', f'P@{k}'])
        recall.append(estatisticas.loc['mean', f'R@{k}'])
        mrr.append(estatisticas.loc['mean', f'MRR@{k}'])
        ndcg.append(estatisticas.loc['mean', f'nDCG@{k}'])

    df = pd.DataFrame({
        "Modelo": mapa_metricas.keys(),
        f"P@{k}": precisao,
        f"R@{k}": recall,
        f"MRR@{k}": mrr,
        f"nDCG@{k}": ndcg
    })
    return df

def compara_metricas_todas_queries(k):
    # Acumula as métricas
    precisao = []
    recall = []
    mrr = []
    ndcg = []

    for nome in mapa_metricas.keys():
        estatisticas = mapa_metricas[nome].describe()
        precisao.append(estatisticas.loc['mean', f'P@{k}'])
        recall.append(estatisticas.loc['mean', f'R@{k}'])
        mrr.append(estatisticas.loc['mean', f'MRR@{k}'])
        ndcg.append(estatisticas.loc['mean', f'nDCG@{k}'])

    df = pd.DataFrame({
        "Modelo": mapa_metricas.keys(),
        f"P@{k}": precisao,
        f"R@{k}": recall,
        f"MRR@{k}": mrr,
        f"nDCG@{k}": ndcg
    })
    return df

pd.set_option('display.precision', 4)

# %%
for con_query in [1, 2, 3]:
    for k in [5, 10]:
        print(f'Resultados para conjunto de query {con_query} e k={k}')
        df_metricas = compara_metricas(con_query, k)
        df_metricas.to_csv(f'{PASTA_RESULTADO_CADERNO}metricas-conj-{con_query}-k-{k}.csv', index=False)
        display(df_metricas)
# Out:
# Resultados para conjunto de query 1 e k=5
#                                               Modelo    P@5     R@5   MRR@5  \
# 0                                        bm25_padrao  0.272  0.1106  0.5253
# 1  bert-base-portuguese-cased-finetuned-tcu-acord...  0.064  0.0253  0.1673
# 2                   bert-large-portuguese-cased_mean  0.084  0.0359  0.1780
# 3               Legal-BERTimbau-sts-large-ma-v3_mean  0.128  0.0523  0.2690
# 4  bert-large-portuguese-cased-legal-mlm-sts-v1.0...  0.244  0.0983  0.4047
# 5         paraphrase-multilingual-mpnet-base-v2_mean  0.188  0.0753  0.3337
# 6                        text-embedding-3-small_mean  0.520  0.2091  0.7433
# 7                        text-embedding-3-large_mean  0.532  0.2164  0.7523
#
#    nDCG@5
# 0  0.2824
# 1  0.0707
# 2  0.0885
# 3  0.1316
# 4  0.2419
# 5  0.1817
# 6  0.5228
# 7  0.5351
# Resultados para conjunto de query 1 e k=10
#                                               Modelo   P@10    R@10  MRR@10  \
# 0                                        bm25_padrao  0.238  0.1966  0.5386
# 1  bert-base-portuguese-cased-finetuned-tcu-acord...  0.044  0.0354  0.1735
# 2                   bert-large-portuguese-cased_mean  0.074  0.0625  0.1988
# 3               Legal-BERTimbau-sts-large-ma-v3_mean  0.108  0.0880  0.2877
# 4  bert-large-portuguese-cased-legal-mlm-sts-v1.0...  0.202  0.1632  0.4240
# 5         paraphrase-multilingual-mpnet-base-v2_mean  0.146  0.1164  0.3512
# 6                        text-embedding-3-small_mean  0.378  0.3069  0.7489
# 7                        text-embedding-3-large_mean  0.408  0.3319  0.7543
#
#    nDCG@10
# 0   0.2753
# 1   0.0560
# 2   0.0833
# 3   0.1214
# 4   0.2261
# 5   0.1608
# 6   0.4454
# 7   0.4733
# Resultados para conjunto de query 2 e k=5
#                                               Modelo    P@5     R@5   MRR@5  \
# 0                                        bm25_padrao  0.500  0.2077  0.8620
# 1  bert-base-portuguese-cased-finetuned-tcu-acord...  0.144  0.0609  0.3513
# 2                   bert-large-portuguese-cased_mean  0.196  0.0838  0.3997
# 3               Legal-BERTimbau-sts-large-ma-v3_mean  0.224  0.0925  0.4497
# 4  bert-large-portuguese-cased-legal-mlm-sts-v1.0...  0.420  0.1726  0.7017
# 5         paraphrase-multilingual-mpnet-base-v2_mean  0.332  0.1345  0.5950
# 6                        text-embedding-3-small_mean  0.604  0.2508  0.8907
# 7                        text-embedding-3-large_mean  0.648  0.2692  0.8890
#
#    nDCG@5
# 0  0.5713
# 1  0.1522
# 2  0.2051
# 3  0.2347
# 4  0.4397
# 5  0.3455
# 6  0.6484
# 7  0.6803
# Resultados para conjunto de query 2 e k=10
#                                               Modelo   P@10    R@10  MRR@10  \
# 0                                        bm25_padrao  0.378  0.3176  0.8665
# 1  bert-base-portuguese-cased-finetuned-tcu-acord...  0.110  0.0921  0.3587
# 2                   bert-large-portuguese-cased_mean  0.156  0.1317  0.4178
# 3               Legal-BERTimbau-sts-large-ma-v3_mean  0.166  0.1372  0.4637
# 4  bert-large-portuguese-cased-legal-mlm-sts-v1.0...  0.302  0.2475  0.7134
# 5         paraphrase-multilingual-mpnet-base-v2_mean  0.246  0.2028  0.6051
# 6                        text-embedding-3-small_mean  0.468  0.3892  0.8951
# 7                        text-embedding-3-large_mean  0.492  0.4077  0.8923
#
#    nDCG@10
# 0   0.5106
# 1   0.1344
# 2   0.1870
# 3   0.2099
# 4   0.3851
# 5   0.3146
# 6   0.5883
# 7   0.6177
# Resultados para conjunto de query 3 e k=5
#                                               Modelo    P@5     R@5   MRR@5  \
# 0                                        bm25_padrao  0.520  0.2340  0.9150
# 1  bert-base-portuguese-cased-finetuned-tcu-acord...  0.296  0.1333  0.5997
# 2                   bert-large-portuguese-cased_mean  0.296  0.1326  0.5983
# 3               Legal-BERTimbau-sts-large-ma-v3_mean  0.236  0.1060  0.4723
# 4  bert-large-portuguese-cased-legal-mlm-sts-v1.0...  0.468  0.2085  0.8647
# 5         paraphrase-multilingual-mpnet-base-v2_mean  0.496  0.2192  0.7823
# 6                        text-embedding-3-small_mean  0.624  0.2775  0.9133
# 7                        text-embedding-3-large_mean  0.632  0.2774  0.9147
#
#    nDCG@5
# 0  0.6030
# 1  0.3392
# 2  0.3287
# 3  0.2599
# 4  0.5283
# 5  0.5351
# 6  0.6752
# 7  0.6882
# Resultados para conjunto de query 3 e k=10
#                                               Modelo   P@10    R@10  MRR@10  \
# 0                                        bm25_padrao  0.388  0.3451  0.9175
# 1  bert-base-portuguese-cased-finetuned-tcu-acord...  0.202  0.1795  0.6083
# 2                   bert-large-portuguese-cased_mean  0.222  0.1964  0.6070
# 3               Legal-BERTimbau-sts-large-ma-v3_mean  0.182  0.1611  0.4921
# 4  bert-large-portuguese-cased-legal-mlm-sts-v1.0...  0.348  0.3065  0.8675
# 5         paraphrase-multilingual-mpnet-base-v2_mean  0.344  0.3047  0.7919
# 6                        text-embedding-3-small_mean  0.482  0.4247  0.9167
# 7                        text-embedding-3-large_mean  0.472  0.4150  0.9147
#
#    nDCG@10
# 0   0.5328
# 1   0.2881
# 2   0.2893
# 3   0.2338
# 4   0.4603
# 5   0.4519
# 6   0.6089
# 7   0.6084

# %%
for k in [20]:
    df_metricas = compara_metricas_todas_queries(k)
    df_metricas.to_csv(f'{PASTA_RESULTADO_CADERNO}metricas-k-{k}.csv', index=False)
    display(df_metricas)
# Out:
#                                                Modelo    P@20    R@20  MRR@20  \
# 0   bert-base-portuguese-cased-finetuned-tcu-acord...  0.0880  0.1518  0.3867
# 1   bert-base-portuguese-cased-finetuned-tcu-acord...  0.0637  0.1066  0.2778
# 2                     bert-base-portuguese-cased_mean  0.0807  0.1390  0.3732
# 3                      bert-base-portuguese-cased_cls  0.0397  0.0666  0.1640
# 4                    bert-large-portuguese-cased_mean  0.1063  0.1825  0.4146
# 5                     bert-large-portuguese-cased_cls  0.0250  0.0433  0.1232
# 6                Legal-BERTimbau-sts-large-ma-v3_mean  0.1117  0.1884  0.4224
# 7                 Legal-BERTimbau-sts-large-ma-v3_cls  0.0577  0.0984  0.2726
# 8   bert-large-portuguese-cased-legal-mlm-sts-v1.0...  0.2033  0.3415  0.6717
# 9   bert-large-portuguese-cased-legal-mlm-sts-v1.0...  0.1600  0.2716  0.5457
# 10  bert-large-portuguese-cased-legal-mlm-nli-sts-...  0.1727  0.2902  0.6120
# 11  bert-large-portuguese-cased-legal-mlm-nli-sts-...  0.1477  0.2510  0.5705
# 12         paraphrase-multilingual-mpnet-base-v2_mean  0.1643  0.2749  0.5851
# 13          paraphrase-multilingual-mpnet-base-v2_cls  0.1007  0.1686  0.5102
#
#     nDCG@20
# 0    0.1801
# 1    0.1237
# 2    0.1695
# 3    0.0698
# 4    0.2099
# 5    0.0471
# 6    0.2154
# 7    0.1186
# 8    0.4011
# 9    0.3124
# 10   0.3494
# 11   0.3039
# 12   0.3356
# 13   0.2266

# %%
# Gravando mapa_metricas
caminho_arquivo = f'{PASTA_RESULTADO_CADERNO}mapa_metricas.pickle'
with open(caminho_arquivo, 'wb') as arquivo_pickle:
    pickle.dump(mapa_metricas, arquivo_pickle)

# %%
mapa_metricas
# Out:
# {'bert-base-portuguese-cased-finetuned-tcu-acordaos_mean':      QUERY_KEY  P@5  P@10  P@20  P@50     R@5    R@10    R@20    R@50   MRR@5  \
#  0            1  0.0   0.0  0.05  0.02  0.0000  0.0000  0.0667  0.0667  0.0000
#  1            2  0.0   0.0  0.05  0.02  0.0000  0.0000  0.1429  0.1429  0.0000
#  2            3  0.0   0.0  0.00  0.00  0.0000  0.0000  0.0000  0.0000  0.0000
#  3            4  0.2   0.2  0.10  0.06  0.0769  0.1538  0.1538  0.2308  0.3333
#  4            5  0.2   0.1  0.10  0.04  0.0769  0.0769  0.1538  0.1538  0.5000
#  ..         ...  ...   ...   ...   ...     ...     ...     ...     ...     ...
#  145        146  0.2   0.1  0.10  0.06  0.0833  0.0833  0.1667  0.2500  1.0000
#  146        147  0.0   0.0  0.05  0.04  0.0000  0.0000  0.0714  0.1429  0.0000
#  147        148  0.0   0.1  0.15  0.10  0.0000  0.0769  0.2308  0.3846  0.0000
#  148        149  0.2   0.1  0.05  0.06  0.0833  0.0833  0.0833  0.2500  1.0000
#  149        150  0.2   0.1  0.10  0.08  0.0909  0.0909  0.1818  0.3636  0.3333
#
#       MRR@10  MRR@20  MRR@50  nDCG@5  nDCG@10  nDCG@20  nDCG@50
#  0    0.0000  0.0667  0.0667  0.0000   0.0000   0.0502   0.0502
#  1    0.0000  0.0667  0.0667  0.0000   0.0000   0.0574   0.0574
#  2    0.0000  0.0000  0.0000  0.0000   0.0000   0.0000   0.0000
#  3    0.3333  0.3333  0.3333  0.1696   0.1834   0.1731   0.2154
#  4    0.5000  0.5000  0.5000  0.2140   0.1389   0.1795   0.1795
#  ..      ...     ...     ...     ...      ...      ...      ...
#  145  1.0000  1.0000  1.0000  0.4350   0.2974   0.3329   0.3675
#  146  0.0000  0.0769  0.0769  0.0000   0.0000   0.0249   0.0661
#  147  0.1000  0.1000  0.1000  0.0000   0.0793   0.1646   0.2370
#  148  1.0000  1.0000  1.0000  0.3547   0.2713   0.2584   0.2937
#  149  0.3333  0.3333  0.3333  0.1696   0.1311   0.1971   0.2940
#
#  [150 rows x 17 columns],
#  'bert-base-portuguese-cased-finetuned-tcu-acordaos_cls':      QUERY_KEY  P@5  P@10  P@20  P@50     R@5    R@10    R@20    R@50   MRR@5  \
#  0            1  0.2   0.1  0.05  0.02  0.0667  0.0667  0.0667  0.0667  0.3333
#  1            2  0.0   0.0  0.00  0.00  0.0000  0.0000  0.0000  0.0000  0.0000
#  2            3  0.4   0.2  0.10  0.06  0.1333  0.1333  0.1333  0.2000  1.0000
#  3            4  0.4   0.2  0.15  0.08  0.1538  0.1538  0.2308  0.3077  0.3333
#  4            5  0.0   0.0  0.00  0.02  0.0000  0.0000  0.0000  0.0769  0.0000
#  ..         ...  ...   ...   ...   ...     ...     ...     ...     ...     ...
#  145        146  0.0   0.0  0.00  0.00  0.0000  0.0000  0.0000  0.0000  0.0000
#  146        147  0.0   0.0  0.00  0.02  0.0000  0.0000  0.0000  0.0714  0.0000
#  147        148  0.0   0.0  0.10  0.08  0.0000  0.0000  0.1538  0.3077  0.0000
#  148        149  0.4   0.2  0.10  0.04  0.1667  0.1667  0.1667  0.1667  1.0000
#  149        150  0.2   0.2  0.10  0.04  0.0909  0.1818  0.1818  0.1818  1.0000
#
#       MRR@10  MRR@20  MRR@50  nDCG@5  nDCG@10  nDCG@20  nDCG@50
#  0    0.3333  0.3333  0.3333  0.1696   0.1100   0.1003   0.1003
#  1    0.0000  0.0000  0.0000  0.0000   0.0000   0.0000   0.0000
#  2    1.0000  1.0000  1.0000  0.3722   0.2587   0.2256   0.2533
#  3    0.3333  0.3333  0.3333  0.3008   0.1952   0.2350   0.2743
#  4    0.0000  0.0000  0.0200  0.0000   0.0000   0.0000   0.0359
#  ..      ...     ...     ...     ...      ...      ...      ...
#  145  0.0000  0.0000  0.0000  0.0000   0.0000   0.0000   0.0000
#  146  0.0000  0.0000  0.0278  0.0000   0.0000   0.0000   0.0363
#  147  0.0000  0.0714  0.0714  0.0000   0.0000   0.1245   0.1930
#  148  1.0000  1.0000  1.0000  0.4919   0.3762   0.3584   0.3584
#  149  1.0000  1.0000  1.0000  0.3392   0.3495   0.3412   0.3412
#
#  [150 rows x 17 columns],
#  'bert-base-portuguese-cased_mean':      QUERY_KEY  P@5  P@10  P@20  P@50     R@5    R@10    R@20    R@50  MRR@5  \
#  0            1  0.0   0.0  0.00  0.04  0.0000  0.0000  0.0000  0.1333    0.0
#  1            2  0.0   0.0  0.00  0.02  0.0000  0.0000  0.0000  0.1429    0.0
#  2            3  0.0   0.0  0.00  0.00  0.0000  0.0000  0.0000  0.0000    0.0
#  3            4  0.4   0.2  0.10  0.06  0.1538  0.1538  0.1538  0.2308    1.0
#  4            5  0.2   0.1  0.05  0.02  0.0769  0.0769  0.0769  0.0769    0.2
#  ..         ...  ...   ...   ...   ...     ...     ...     ...     ...    ...
#  145        146  0.0   0.1  0.05  0.04  0.0000  0.0833  0.0833  0.1667    0.0
#  146        147  0.0   0.0  0.00  0.00  0.0000  0.0000  0.0000  0.0000    0.0
#  147        148  0.0   0.0  0.15  0.10  0.0000  0.0000  0.2308  0.3846    0.0
#  148        149  0.2   0.1  0.05  0.06  0.0833  0.0833  0.0833  0.2500    1.0
#  149        150  0.2   0.1  0.10  0.08  0.0909  0.0909  0.1818  0.3636    1.0
#
#       MRR@10  MRR@20  MRR@50  nDCG@5  nDCG@10  nDCG@20  nDCG@50
#  0     0.000  0.0000  0.0286  0.0000   0.0000   0.0000   0.0756
#  1     0.000  0.0000  0.0345  0.0000   0.0000   0.0000   0.0468
#  2     0.000  0.0000  0.0000  0.0000   0.0000   0.0000   0.0000
#  3     1.000  1.0000  1.0000  0.5087   0.3301   0.3116   0.3501
#  4     0.200  0.2000  0.2000  0.1312   0.0851   0.0788   0.0788
#  ..      ...     ...     ...     ...      ...      ...      ...
#  145   0.125  0.1250  0.1250  0.0000   0.0938   0.0890   0.1236
#  146   0.000  0.0000  0.0000  0.0000   0.0000   0.0000   0.0000
#  147   0.000  0.0833  0.0833  0.0000   0.0000   0.1574   0.2220
#  148   1.000  1.0000  1.0000  0.3547   0.2713   0.2584   0.2950
#  149   1.000  1.0000  1.0000  0.3392   0.2621   0.3185   0.4148
#
#  [150 rows x 17 columns],
#  'bert-base-portuguese-cased_cls':      QUERY_KEY  P@5  P@10  P@20  P@50     R@5    R@10    R@20    R@50  MRR@5  \
#  0            1  0.0   0.0  0.00  0.02  0.0000  0.0000  0.0000  0.0667    0.0
#  1            2  0.0   0.0  0.00  0.00  0.0000  0.0000  0.0000  0.0000    0.0
#  2            3  0.4   0.2  0.10  0.06  0.1333  0.1333  0.1333  0.2000    1.0
#  3            4  0.4   0.3  0.20  0.08  0.1538  0.2308  0.3077  0.3077    0.5
#  4            5  0.0   0.0  0.00  0.00  0.0000  0.0000  0.0000  0.0000    0.0
#  ..         ...  ...   ...   ...   ...     ...     ...     ...     ...    ...
#  145        146  0.0   0.0  0.00  0.00  0.0000  0.0000  0.0000  0.0000    0.0
#  146        147  0.0   0.0  0.00  0.00  0.0000  0.0000  0.0000  0.0000    0.0
#  147        148  0.0   0.0  0.00  0.04  0.0000  0.0000  0.0000  0.1538    0.0
#  148        149  0.4   0.2  0.10  0.04  0.1667  0.1667  0.1667  0.1667    0.5
#  149        150  0.2   0.1  0.05  0.02  0.0909  0.0909  0.0909  0.0909    1.0
#
#       MRR@10  MRR@20  MRR@50  nDCG@5  nDCG@10  nDCG@20  nDCG@50
#  0       0.0     0.0  0.0200  0.0000   0.0000   0.0000   0.0354
#  1       0.0     0.0  0.0000  0.0000   0.0000   0.0000   0.0000
#  2       1.0     1.0  1.0000  0.3573   0.2484   0.2166   0.2302
#  3       0.5     0.5  0.5000  0.3836   0.3152   0.3463   0.3463
#  4       0.0     0.0  0.0000  0.0000   0.0000   0.0000   0.0000
#  ..      ...     ...     ...     ...      ...      ...      ...
#  145     0.0     0.0  0.0000  0.0000   0.0000   0.0000   0.0000
#  146     0.0     0.0  0.0000  0.0000   0.0000   0.0000   0.0000
#  147     0.0     0.0  0.0455  0.0000   0.0000   0.0000   0.0888
#  148     0.5     0.5  0.5000  0.3610   0.2761   0.2630   0.2630
#  149     1.0     1.0  1.0000  0.3392   0.2621   0.2559   0.2559
#
#  [150 rows x 17 columns],
#  'bert-large-portuguese-cased_mean':      QUERY_KEY  P@5  P@10  P@20  P@50     R@5    R@10    R@20    R@50   MRR@5  \
#  0            1  0.0   0.0  0.10  0.04  0.0000  0.0000  0.1333  0.1333  0.0000
#  1            2  0.0   0.1  0.15  0.06  0.0000  0.1429  0.4286  0.4286  0.0000
#  2            3  0.0   0.2  0.15  0.06  0.0000  0.1333  0.2000  0.2000  0.0000
#  3            4  0.2   0.2  0.10  0.04  0.0769  0.1538  0.1538  0.1538  0.5000
#  4            5  0.0   0.0  0.05  0.04  0.0000  0.0000  0.0769  0.1538  0.0000
#  ..         ...  ...   ...   ...   ...     ...     ...     ...     ...     ...
#  145        146  0.0   0.0  0.00  0.02  0.0000  0.0000  0.0000  0.0833  0.0000
#  146        147  0.0   0.0  0.05  0.06  0.0000  0.0000  0.0714  0.2143  0.0000
#  147        148  0.4   0.3  0.15  0.12  0.1538  0.2308  0.2308  0.4615  0.3333
#  148        149  0.4   0.3  0.15  0.08  0.1667  0.2500  0.2500  0.3333  1.0000
#  149        150  0.4   0.2  0.15  0.10  0.1818  0.1818  0.2727  0.4545  1.0000
#
#       MRR@10  MRR@20  MRR@50  nDCG@5  nDCG@10  nDCG@20  nDCG@50
#  0    0.0000  0.0556  0.0556  0.0000   0.0000   0.0937   0.0937
#  1    0.1000  0.1000  0.1000  0.0000   0.0663   0.2089   0.2089
#  2    0.1429  0.1429  0.1429  0.0000   0.1240   0.1441   0.1441
#  3    0.5000  0.5000  0.5000  0.2140   0.2025   0.1911   0.1911
#  4    0.0000  0.0588  0.0588  0.0000   0.0000   0.0489   0.0880
#  ..      ...     ...     ...     ...      ...      ...      ...
#  145  0.0000  0.0000  0.0385  0.0000   0.0000   0.0000   0.0593
#  146  0.0000  0.0526  0.0526  0.0000   0.0000   0.0438   0.0980
#  147  0.3333  0.3333  0.3333  0.3478   0.3106   0.2891   0.3873
#  148  1.0000  1.0000  1.0000  0.4004   0.3364   0.3205   0.3722
#  149  1.0000  1.0000  1.0000  0.5087   0.3932   0.4452   0.5295
#
#  [150 rows x 17 columns],
#  'bert-large-portuguese-cased_cls':      QUERY_KEY  P@5  P@10  P@20  P@50     R@5    R@10    R@20    R@50  MRR@5  \
#  0            1  0.0   0.0  0.00  0.02  0.0000  0.0000  0.0000  0.0667    0.0
#  1            2  0.0   0.0  0.05  0.02  0.0000  0.0000  0.1429  0.1429    0.0
#  2            3  0.2   0.1  0.05  0.02  0.0667  0.0667  0.0667  0.0667    0.5
#  3            4  0.2   0.1  0.05  0.04  0.0769  0.0769  0.0769  0.1538    1.0
#  4            5  0.0   0.0  0.00  0.00  0.0000  0.0000  0.0000  0.0000    0.0
#  ..         ...  ...   ...   ...   ...     ...     ...     ...     ...    ...
#  145        146  0.0   0.0  0.00  0.00  0.0000  0.0000  0.0000  0.0000    0.0
#  146        147  0.0   0.0  0.00  0.00  0.0000  0.0000  0.0000  0.0000    0.0
#  147        148  0.0   0.0  0.00  0.00  0.0000  0.0000  0.0000  0.0000    0.0
#  148        149  0.0   0.0  0.00  0.00  0.0000  0.0000  0.0000  0.0000    0.0
#  149        150  0.2   0.1  0.05  0.02  0.0909  0.0909  0.0909  0.0909    0.5
#
#       MRR@10  MRR@20  MRR@50  nDCG@5  nDCG@10  nDCG@20  nDCG@50
#  0       0.0  0.0000  0.0370  0.0000   0.0000   0.0000   0.0417
#  1       0.0  0.0556  0.0556  0.0000   0.0000   0.0810   0.0810
#  2       0.5  0.5000  0.5000  0.2140   0.1487   0.1297   0.1297
#  3       1.0  1.0000  1.0000  0.3392   0.2201   0.2077   0.2505
#  4       0.0  0.0000  0.0000  0.0000   0.0000   0.0000   0.0000
#  ..      ...     ...     ...     ...      ...      ...      ...
#  145     0.0  0.0000  0.0000  0.0000   0.0000   0.0000   0.0000
#  146     0.0  0.0000  0.0000  0.0000   0.0000   0.0000   0.0000
#  147     0.0  0.0000  0.0000  0.0000   0.0000   0.0000   0.0000
#  148     0.0  0.0000  0.0000  0.0000   0.0000   0.0000   0.0000
#  149     0.5  0.5000  0.5000  0.2140   0.1654   0.1614   0.1614
#
#  [150 rows x 17 columns],
#  'Legal-BERTimbau-sts-large-ma-v3_mean':      QUERY_KEY  P@5  P@10  P@20  P@50     R@5    R@10    R@20    R@50   MRR@5  \
#  0            1  0.0   0.2  0.10  0.08  0.0000  0.1333  0.1333  0.2667  0.0000
#  1            2  0.0   0.0  0.00  0.00  0.0000  0.0000  0.0000  0.0000  0.0000
#  2            3  0.0   0.2  0.15  0.08  0.0000  0.1333  0.2000  0.2667  0.0000
#  3            4  0.0   0.0  0.05  0.02  0.0000  0.0000  0.0769  0.0769  0.0000
#  4            5  0.2   0.1  0.10  0.08  0.0769  0.0769  0.1538  0.3077  0.5000
#  ..         ...  ...   ...   ...   ...     ...     ...     ...     ...     ...
#  145        146  0.0   0.1  0.05  0.04  0.0000  0.0833  0.0833  0.1667  0.0000
#  146        147  0.0   0.1  0.05  0.04  0.0000  0.0714  0.0714  0.1429  0.0000
#  147        148  0.4   0.3  0.15  0.08  0.1538  0.2308  0.2308  0.3077  0.3333
#  148        149  0.4   0.3  0.20  0.08  0.1667  0.2500  0.3333  0.3333  1.0000
#  149        150  0.2   0.2  0.10  0.06  0.0909  0.1818  0.1818  0.2727  0.3333
#
#       MRR@10  MRR@20  MRR@50  nDCG@5  nDCG@10  nDCG@20  nDCG@50
#  0    0.1667  0.1667  0.1667  0.0000   0.1447   0.1319   0.2213
#  1    0.0000  0.0000  0.0000  0.0000   0.0000   0.0000   0.0000
#  2    0.1250  0.1250  0.1250  0.0000   0.0950   0.0987   0.1442
#  3    0.0000  0.0833  0.0833  0.0000   0.0000   0.0561   0.0561
#  4    0.5000  0.5000  0.5000  0.2140   0.1389   0.1765   0.2661
#  ..      ...     ...     ...     ...      ...      ...      ...
#  145  0.1000  0.1000  0.1000  0.0000   0.0860   0.0815   0.1182
#  146  0.1429  0.1429  0.1429  0.0000   0.0702   0.0631   0.1056
#  147  0.3333  0.3333  0.3333  0.3314   0.3086   0.2873   0.3181
#  148  1.0000  1.0000  1.0000  0.5320   0.4853   0.5322   0.5322
#  149  0.3333  0.3333  0.3333  0.1696   0.2184   0.2132   0.2596
#
#  [150 rows x 17 columns],
#  'Legal-BERTimbau-sts-large-ma-v3_cls':      QUERY_KEY  P@5  P@10  P@20  P@50     R@5    R@10    R@20    R@50   MRR@5  \
#  0            1  0.0   0.0  0.00  0.02  0.0000  0.0000  0.0000  0.0667  0.0000
#  1            2  0.0   0.0  0.00  0.00  0.0000  0.0000  0.0000  0.0000  0.0000
#  2            3  0.0   0.0  0.00  0.00  0.0000  0.0000  0.0000  0.0000  0.0000
#  3            4  0.0   0.0  0.00  0.00  0.0000  0.0000  0.0000  0.0000  0.0000
#  4            5  0.0   0.0  0.00  0.00  0.0000  0.0000  0.0000  0.0000  0.0000
#  ..         ...  ...   ...   ...   ...     ...     ...     ...     ...     ...
#  145        146  0.0   0.0  0.00  0.02  0.0000  0.0000  0.0000  0.0833  0.0000
#  146        147  0.0   0.0  0.00  0.02  0.0000  0.0000  0.0000  0.0714  0.0000
#  147        148  0.2   0.3  0.15  0.06  0.0769  0.2308  0.2308  0.2308  0.2000
#  148        149  0.2   0.1  0.10  0.06  0.0833  0.0833  0.1667  0.2500  0.3333
#  149        150  0.2   0.1  0.05  0.02  0.0909  0.0909  0.0909  0.0909  0.3333
#
#       MRR@10  MRR@20  MRR@50  nDCG@5  nDCG@10  nDCG@20  nDCG@50
#  0    0.0000  0.0000  0.0244  0.0000   0.0000   0.0000   0.0372
#  1    0.0000  0.0000  0.0000  0.0000   0.0000   0.0000   0.0000
#  2    0.0000  0.0000  0.0000  0.0000   0.0000   0.0000   0.0000
#  3    0.0000  0.0000  0.0000  0.0000   0.0000   0.0000   0.0000
#  4    0.0000  0.0000  0.0000  0.0000   0.0000   0.0000   0.0000
#  ..      ...     ...     ...     ...      ...      ...      ...
#  145  0.0000  0.0000  0.0312  0.0000   0.0000   0.0000   0.0559
#  146  0.0000  0.0000  0.0208  0.0000   0.0000   0.0000   0.0337
#  147  0.2000  0.2000  0.2000  0.1446   0.2507   0.2334   0.2334
#  148  0.3333  0.3333  0.3333  0.1773   0.1356   0.1925   0.2451
#  149  0.3333  0.3333  0.3333  0.1696   0.1311   0.1279   0.1279
#
#  [150 rows x 17 columns],
#  'bert-large-portuguese-cased-legal-mlm-sts-v1.0_mean':      QUERY_KEY  P@5  P@10  P@20  P@50     R@5    R@10    R@20    R@50  MRR@5  \
#  0            1  0.0   0.0  0.10  0.10  0.0000  0.0000  0.1333  0.3333    0.0
#  1            2  0.0   0.0  0.05  0.04  0.0000  0.0000  0.1429  0.2857    0.0
#  2            3  0.2   0.1  0.10  0.12  0.0667  0.0667  0.1333  0.4000    0.2
#  3            4  0.0   0.2  0.20  0.12  0.0000  0.1538  0.3077  0.4615    0.0
#  4            5  0.4   0.2  0.10  0.04  0.1538  0.1538  0.1538  0.1538    1.0
#  ..         ...  ...   ...   ...   ...     ...     ...     ...     ...    ...
#  145        146  0.2   0.1  0.15  0.08  0.0833  0.0833  0.2500  0.3333    1.0
#  146        147  0.0   0.0  0.05  0.06  0.0000  0.0000  0.0714  0.2143    0.0
#  147        148  0.6   0.4  0.25  0.18  0.2308  0.3077  0.3846  0.6923    1.0
#  148        149  0.2   0.2  0.25  0.14  0.0833  0.1667  0.4167  0.5833    1.0
#  149        150  0.6   0.3  0.25  0.16  0.2727  0.2727  0.4545  0.7273    1.0
#
#       MRR@10  MRR@20  MRR@50  nDCG@5  nDCG@10  nDCG@20  nDCG@50
#  0    0.0000  0.0909  0.0909  0.0000   0.0000   0.1017   0.2204
#  1    0.0000  0.0625  0.0625  0.0000   0.0000   0.0842   0.1543
#  2    0.2000  0.2000  0.2000  0.0875   0.0608   0.0890   0.2364
#  3    0.1667  0.1667  0.1667  0.0000   0.1447   0.2425   0.3295
#  4    1.0000  1.0000  1.0000  0.4704   0.3052   0.2826   0.2826
#  ..      ...     ...     ...     ...      ...      ...      ...
#  145  1.0000  1.0000  1.0000  0.4350   0.2974   0.3764   0.4143
#  146  0.0000  0.0667  0.0667  0.0000   0.0000   0.0473   0.1159
#  147  1.0000  1.0000  1.0000  0.7704   0.6188   0.6148   0.7595
#  148  1.0000  1.0000  1.0000  0.3547   0.2974   0.4119   0.5200
#  149  1.0000  1.0000  1.0000  0.6844   0.5289   0.6191   0.7188
#
#  [150 rows x 17 columns],
#  'bert-large-portuguese-cased-legal-mlm-sts-v1.0_cls':      QUERY_KEY  P@5  P@10  P@20  P@50     R@5    R@10    R@20    R@50  MRR@5  \
#  0            1  0.2   0.1  0.05  0.06  0.0667  0.0667  0.0667  0.2000    0.2
#  1            2  0.0   0.0  0.00  0.00  0.0000  0.0000  0.0000  0.0000    0.0
#  2            3  0.0   0.0  0.05  0.10  0.0000  0.0000  0.0667  0.3333    0.0
#  3            4  0.0   0.2  0.15  0.10  0.0000  0.1538  0.2308  0.3846    0.0
#  4            5  0.0   0.1  0.10  0.04  0.0000  0.0769  0.1538  0.1538    0.0
#  ..         ...  ...   ...   ...   ...     ...     ...     ...     ...    ...
#  145        146  0.4   0.3  0.20  0.08  0.1667  0.2500  0.3333  0.3333    1.0
#  146        147  0.0   0.0  0.00  0.06  0.0000  0.0000  0.0000  0.2143    0.0
#  147        148  0.4   0.3  0.25  0.14  0.1538  0.2308  0.3846  0.5385    1.0
#  148        149  0.2   0.1  0.10  0.10  0.0833  0.0833  0.1667  0.4167    1.0
#  149        150  0.6   0.4  0.35  0.16  0.2727  0.3636  0.6364  0.7273    1.0
#
#       MRR@10  MRR@20  MRR@50  nDCG@5  nDCG@10  nDCG@20  nDCG@50
#  0    0.2000  0.2000  0.2000  0.1312   0.0851   0.0776   0.1541
#  1    0.0000  0.0000  0.0000  0.0000   0.0000   0.0000   0.0000
#  2    0.0000  0.0833  0.0833  0.0000   0.0000   0.0370   0.1578
#  3    0.1667  0.1667  0.1667  0.0000   0.1518   0.1941   0.2757
#  4    0.1111  0.1111  0.1111  0.0000   0.0663   0.1149   0.1149
#  ..      ...     ...     ...     ...      ...      ...      ...
#  145  1.0000  1.0000  1.0000  0.6179   0.4851   0.5051   0.5051
#  146  0.0000  0.0000  0.0435  0.0000   0.0000   0.0000   0.1103
#  147  1.0000  1.0000  1.0000  0.6095   0.5270   0.5688   0.6384
#  148  1.0000  1.0000  1.0000  0.3547   0.2713   0.3217   0.4529
#  149  1.0000  1.0000  1.0000  0.6992   0.5667   0.7224   0.7544
#
#  [150 rows x 17 columns],
#  'bert-large-portuguese-cased-legal-mlm-nli-sts-v1_mean':      QUERY_KEY  P@5  P@10  P@20  P@50     R@5    R@10    R@20    R@50   MRR@5  \
#  0            1  0.0   0.0  0.05  0.12  0.0000  0.0000  0.0667  0.4000  0.0000
#  1            2  0.2   0.1  0.05  0.04  0.1429  0.1429  0.1429  0.2857  1.0000
#  2            3  0.2   0.2  0.20  0.08  0.0667  0.1333  0.2667  0.2667  0.2500
#  3            4  0.2   0.3  0.20  0.16  0.0769  0.2308  0.3077  0.6154  0.2000
#  4            5  0.2   0.1  0.10  0.04  0.0769  0.0769  0.1538  0.1538  0.2500
#  ..         ...  ...   ...   ...   ...     ...     ...     ...     ...     ...
#  145        146  0.2   0.1  0.10  0.06  0.0833  0.0833  0.1667  0.2500  0.3333
#  146        147  0.2   0.1  0.05  0.06  0.0714  0.0714  0.0714  0.2143  0.2500
#  147        148  1.0   0.6  0.35  0.14  0.3846  0.4615  0.5385  0.5385  1.0000
#  148        149  0.6   0.3  0.25  0.18  0.2500  0.2500  0.4167  0.7500  1.0000
#  149        150  0.6   0.6  0.45  0.18  0.2727  0.5455  0.8182  0.8182  0.5000
#
#       MRR@10  MRR@20  MRR@50  nDCG@5  nDCG@10  nDCG@20  nDCG@50
#  0    0.0000  0.0625  0.0625  0.0000   0.0000   0.0491   0.2405
#  1    1.0000  1.0000  1.0000  0.3737   0.3441   0.3441   0.3862
#  2    0.2500  0.2500  0.2500  0.0974   0.1237   0.1952   0.1952
#  3    0.2000  0.2000  0.2000  0.1312   0.2369   0.2768   0.4459
#  4    0.2500  0.2500  0.2500  0.1461   0.0948   0.1399   0.1399
#  ..      ...     ...     ...     ...      ...      ...      ...
#  145  0.3333  0.3333  0.3333  0.2175   0.1487   0.1845   0.2180
#  146  0.2500  0.2500  0.2500  0.1249   0.0907   0.0815   0.1392
#  147  1.0000  1.0000  1.0000  0.9859   0.7819   0.7695   0.7695
#  148  1.0000  1.0000  1.0000  0.6294   0.4814   0.5424   0.6779
#  149  0.5000  0.5000  0.5000  0.4731   0.5754   0.6938   0.6938
#
#  [150 rows x 17 columns],
#  'bert-large-portuguese-cased-legal-mlm-nli-sts-v1_cls':      QUERY_KEY  P@5  P@10  P@20  P@50     R@5    R@10    R@20    R@50   MRR@5  \
#  0            1  0.0   0.1  0.15  0.06  0.0000  0.0667  0.2000  0.2000  0.0000
#  1            2  0.2   0.1  0.05  0.04  0.1429  0.1429  0.1429  0.2857  1.0000
#  2            3  0.2   0.1  0.15  0.12  0.0667  0.0667  0.2000  0.4000  0.2500
#  3            4  0.2   0.1  0.15  0.12  0.0769  0.0769  0.2308  0.4615  0.2500
#  4            5  0.2   0.2  0.10  0.04  0.0769  0.1538  0.1538  0.1538  0.5000
#  ..         ...  ...   ...   ...   ...     ...     ...     ...     ...     ...
#  145        146  0.0   0.1  0.05  0.06  0.0000  0.0833  0.0833  0.2500  0.0000
#  146        147  0.2   0.1  0.10  0.04  0.0714  0.0714  0.1429  0.1429  0.3333
#  147        148  1.0   0.5  0.35  0.14  0.3846  0.3846  0.5385  0.5385  1.0000
#  148        149  0.4   0.3  0.20  0.16  0.1667  0.2500  0.3333  0.6667  1.0000
#  149        150  0.8   0.6  0.40  0.18  0.3636  0.5455  0.7273  0.8182  0.5000
#
#       MRR@10  MRR@20  MRR@50  nDCG@5  nDCG@10  nDCG@20  nDCG@50
#  0    0.1429  0.1429  0.1429  0.0000   0.0734   0.1607   0.1607
#  1    1.0000  1.0000  1.0000  0.3737   0.3441   0.3441   0.3646
#  2    0.2500  0.2500  0.2500  0.0974   0.0677   0.1273   0.2264
#  3    0.2500  0.2500  0.2500  0.1461   0.0948   0.2006   0.3227
#  4    0.5000  0.5000  0.5000  0.2140   0.2122   0.1965   0.1965
#  ..      ...     ...     ...     ...      ...      ...      ...
#  145  0.1250  0.1250  0.1250  0.0000   0.0938   0.0890   0.1683
#  146  0.3333  0.3333  0.3333  0.1450   0.1053   0.1166   0.1166
#  147  1.0000  1.0000  1.0000  0.9859   0.7242   0.7649   0.7649
#  148  1.0000  1.0000  1.0000  0.5074   0.4143   0.4143   0.5832
#  149  0.5000  0.5000  0.5000  0.6171   0.6492   0.6933   0.7305
#
#  [150 rows x 17 columns],
#  'paraphrase-multilingual-mpnet-base-v2_mean':      QUERY_KEY  P@5  P@10  P@20  P@50     R@5    R@10    R@20    R@50   MRR@5  \
#  0            1  0.0   0.0  0.00  0.00  0.0000  0.0000  0.0000  0.0000  0.0000
#  1            2  0.0   0.0  0.00  0.00  0.0000  0.0000  0.0000  0.0000  0.0000
#  2            3  0.0   0.2  0.20  0.10  0.0000  0.1333  0.2667  0.3333  0.0000
#  3            4  0.6   0.4  0.20  0.14  0.2308  0.3077  0.3077  0.5385  1.0000
#  4            5  0.2   0.2  0.10  0.06  0.0769  0.1538  0.1538  0.2308  0.3333
#  ..         ...  ...   ...   ...   ...     ...     ...     ...     ...     ...
#  145        146  0.2   0.1  0.10  0.08  0.0833  0.0833  0.1667  0.3333  1.0000
#  146        147  0.0   0.0  0.15  0.08  0.0000  0.0000  0.2143  0.2857  0.0000
#  147        148  0.8   0.5  0.30  0.16  0.3077  0.3846  0.4615  0.6154  1.0000
#  148        149  0.4   0.3  0.20  0.10  0.1667  0.2500  0.3333  0.4167  1.0000
#  149        150  0.8   0.5  0.30  0.18  0.3636  0.4545  0.5455  0.8182  1.0000
#
#       MRR@10  MRR@20  MRR@50  nDCG@5  nDCG@10  nDCG@20  nDCG@50
#  0    0.0000  0.0000  0.0000  0.0000   0.0000   0.0000   0.0000
#  1    0.0000  0.0000  0.0000  0.0000   0.0000   0.0000   0.0000
#  2    0.1667  0.1667  0.1667  0.0000   0.1313   0.2194   0.2573
#  3    1.0000  1.0000  1.0000  0.6548   0.4944   0.4666   0.5914
#  4    0.3333  0.3333  0.3333  0.1696   0.1834   0.1698   0.2127
#  ..      ...     ...     ...     ...      ...      ...      ...
#  145  1.0000  1.0000  1.0000  0.4350   0.2974   0.3345   0.4177
#  146  0.0000  0.0909  0.0909  0.0000   0.0000   0.1215   0.1566
#  147  1.0000  1.0000  1.0000  0.8132   0.6799   0.6765   0.7278
#  148  1.0000  1.0000  1.0000  0.5320   0.4713   0.5137   0.5447
#  149  1.0000  1.0000  1.0000  0.7714   0.6544   0.6981   0.8000
#
#  [150 rows x 17 columns],
#  'paraphrase-multilingual-mpnet-base-v2_cls':      QUERY_KEY  P@5  P@10  P@20  P@50     R@5    R@10    R@20    R@50   MRR@5  \
#  0            1  0.0   0.1  0.05  0.06  0.0000  0.0667  0.0667  0.2000  0.0000
#  1            2  0.0   0.0  0.00  0.02  0.0000  0.0000  0.0000  0.1429  0.0000
#  2            3  0.4   0.2  0.10  0.06  0.1333  0.1333  0.1333  0.2000  1.0000
#  3            4  0.2   0.1  0.20  0.10  0.0769  0.0769  0.3077  0.3846  1.0000
#  4            5  0.0   0.0  0.00  0.00  0.0000  0.0000  0.0000  0.0000  0.0000
#  ..         ...  ...   ...   ...   ...     ...     ...     ...     ...     ...
#  145        146  0.4   0.2  0.10  0.04  0.1667  0.1667  0.1667  0.1667  0.3333
#  146        147  0.2   0.1  0.05  0.06  0.0714  0.0714  0.0714  0.2143  0.3333
#  147        148  0.4   0.4  0.25  0.16  0.1538  0.3077  0.3846  0.6154  1.0000
#  148        149  0.4   0.2  0.15  0.08  0.1667  0.1667  0.2500  0.3333  1.0000
#  149        150  0.4   0.2  0.15  0.06  0.1818  0.1818  0.2727  0.2727  1.0000
#
#       MRR@10  MRR@20  MRR@50  nDCG@5  nDCG@10  nDCG@20  nDCG@50
#  0    0.1000  0.1000  0.1000  0.0000   0.0636   0.0580   0.1416
#  1    0.0000  0.0000  0.0294  0.0000   0.0000   0.0000   0.0671
#  2    1.0000  1.0000  1.0000  0.4401   0.3059   0.2668   0.3100
#  3    1.0000  1.0000  1.0000  0.3392   0.2201   0.3703   0.4086
#  4    0.0000  0.0000  0.0000  0.0000   0.0000   0.0000   0.0000
#  ..      ...     ...     ...     ...      ...      ...      ...
#  145  0.3333  0.3333  0.3333  0.3323   0.2272   0.2155   0.2155
#  146  0.3333  0.3333  0.3333  0.0725   0.0526   0.0473   0.1227
#  147  1.0000  1.0000  1.0000  0.6095   0.5664   0.5911   0.6700
#  148  1.0000  1.0000  1.0000  0.5074   0.3881   0.4128   0.4624
#  149  1.0000  1.0000  1.0000  0.4704   0.3635   0.4262   0.4262
#
#  [150 rows x 17 columns]}
